# %% [markdown]
# ####  Step 1 : Install required libraries

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\projects\ml algorithms\linear regression\lr\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in d:\projects\ml algorithms\linear regression\lr\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\projects\ml algorithms\linear regression\lr\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\projects\ml algorithms\linear regression\lr\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\projects\ml algorithms\linear regression\lr\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Step 2 : Import required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Step 3 : Load datset

# %%
from sklearn.datasets import load_diabetes

data = load_diabetes(as_frame=True)5
df = data.frame

df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %% [markdown]
# #### Step 4 : Select features(X) and target(Y)

# %%
x=df[['bmi']]
y=df['target']

# %% [markdown]
# #### Step 5 : Split data into train and test

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,y_train,y_test = train_test_split(
    x,y,test_size=0.2,random_state=42
)

# %% [markdown]
# #### Step 6 : Create model

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %% [markdown]
# #### Step 7 : Train the model

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Step 7 : Make prediction

# %%
y_pred=model.predict(x_test)

# %% [markdown]
# #### Step 9 : Evaluate model

# %%
from sklearn.metrics import mean_squared_error

mse=mean_squared_error(y_test,y_pred)
print("MSE",mse)
# Out:
# MSE 4061.8259284949268

# %% [markdown]
# #### Step 10 : Visualize

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred,color='red')
plt.xlabel("BMI")
plt.ylabel("target")
plt.show()
